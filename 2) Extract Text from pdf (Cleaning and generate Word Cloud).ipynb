# %%
# import library for rd, wr Pdf
import PyPDF2

# %%
# open pdf document
pdf_document = open('C:/Users/Alessandro/Desktop/discorso mattarella.pdf','rb')

# %%
# create a reader object for pdf document
pdf_reader = PyPDF2.PdfFileReader(pdf_document)

# %%
# grab all the text from this PDF file
# List of every page's text in pdf_text.
# The index will correspond to the page number.


pdf_text = [0]  # zero is a placehoder to make page 1 = index 1

pdf_reader = PyPDF2.PdfFileReader(pdf_document)

for p in range(pdf_reader.numPages):
    
    page = pdf_reader.getPage(p)
    
    pdf_text.append(page.extractText())


#pdf_document.close()  

print(pdf_text)
# Out:
# [0, 'Questa sera, care concittadine e cari concittadini, entriamo negli anni venti\n \ndel nuovo secolo. \n \nSi avvia a conclusione un decennio impegnativo, contrass\negnato da una lunga crisi economica e da \nmutamenti tanto veloci quanto impetuosi.\n \nIn questo tempo sono cambiate molte cose attorno a noi, nella nostra vita e nella società.\n \nDesidero,\n \nanzitutto,\n \n\nta per iniziare.\n \nSi tratta,\n \nanche,\n \n\n\n \ninsieme \n-\n \n\n \nnostre riflessioni; senza, naturalmente, trascurare il presente e i suoi problemi, ma anche rendendosi \nconto che il futuro, in realtà, è g\nià cominciato. \n \n \n \n \n \n \n \n \n \n \n\n \nVe ne sono tante sul web, ma questa mi ha fatto riflettere perché proviene da una astronauta, adesso \nal vertice di un Paese amico. \n \nVorrei condividere\n \ncon vo\ni questa immagine. \n \nCon un invito: proviamo\n \n\n \ndal di fuori, allargando lo sguardo oltre il consueto.\n \n\n \n\n \nCome vedono il nostro bel Paese, proteso nel Mediterraneo e posto, per geografia e per stor\nia, come \n\n \nQuesta condizione ha contribuito a costruire\n \nla nostra identità,\n \nsinonimo di sapienza, genio, \narmonia, umanità.\n \n\n \n\nsi apre, celebreremo Raffaello. E subito dopo\n \nrenderemo omaggio a Dante Alighieri.\n \n\n \nRegistro ovunque una grande apertura verso di noi, un forte deside\nrio di collaborazione.\n \nSimpatia\n \nnei confronti del nostro popolo. Non soltanto per il richiamo della sua arte\n \ne dei paesaggi, per la sua \ncreatività e per il suo stile di vita; ma anche per la sua politica di pace, per la ricerca\n \ne la capacità \nitaliana di di\nalogo nel rispetto reciproco, per le missioni\n \ndelle sue Forze Armate in favore della \n\ndei nostri concittadini. \n \n \nVi è una diffusa\n \ndomanda di Italia. \n \nAbbiamo problemi\n \nda non sottovalutare. \n \nIl lavoro\n \nche manca per tanti, anzitutto. Forti\n \ndiseguaglianze. Alcune\n \ngravi crisi aziendali. \n\n \nsistema produttivo. Ma abbiamo ampie possibilità\n \nper affrontare e \nrisolvere \nquesti problemi. E per svolgere inoltre\n \nun ruolo incisivo nella nostra Europa e nella intera \ncomunità\n \ninternazionale. \n \n', '\n \nQuella stessa fiducia con cui si guarda, da fuori, verso il nostro Paese\n \ndeve indurci ad averne di più \nin noi \nstessi, per dar corpo alla\n \nsperanza di un futuro migliore.\n \nConosco le difficoltà e le ferite presenti nelle\n \nnostre comunità. Le attese di\n \ntanti italiani. \n \n \nDobbiamo aver fiducia e impegnarci attivamente nel comune interesse. Disponiamo di grandi \nrisorse. D\ni umanità, di ingegno, di capacità di impresa. Tutto questo produce esperienze\n \nimportanti, \nbuone pratiche\n \ndi grande rilievo. Ne ho avuto conoscenza diretta\n \nvisitando i nostri territori. \n \n\nfare. \n \nDobbiamo\n \ncreare le condizioni\n \nche consentano\n \na tutte le risorse di cui disponiamo di emergere e di \nesprimersi senza ostacoli e difficoltà. \n \n \n \n \nCon spirito\n \ne atteggiamento di reciproca solidarietà.\n \nInsieme.\n \nIn particolar modo è necessario ridurre il \ndivario che sta ulteriormente crescendo tra Nord e Sud \n\nfrenato nelle\n \nsue potenzialità di sviluppo.\n \nNaturalmente, per promuovere fiducia, è decisivo il buon funz\nionamento delle pubbliche istituzioni \nche devono alimentarla, favorendo coesione sociale. Questo è possibile\n \nassicurando decisioni\n \nadeguate, efficaci\n \ne tempestive sui temi della vita concreta dei cittadini.\n \nLa democrazia si rafforza se le istituzioni tengo\nno viva una\n \nragionevole speranza.\n \n\n \nsviluppare, sempre di più, una cultura della\n \nresponsabilità che riguarda tutti: \ndalle formazioni politiche,\n \nai singoli cittadini, alle imprese, alle formazioni intermedie, alle \nassociazioni raccolte int\norno a interessi\n \ne a valori. \n \nLa cultura della responsabilità costituisce il più forte presidio di libertà e di difesa dei principi, su \ncui si fonda la\n \nRepubblica. Questo comune se ...

# %%
type(pdf_text)
# Out:
# list

# %% [markdown]
# --------

# %% [markdown]
# Cleaning text

# %%
# Import spaCy and load the italian language library
import spacy
import it_core_news_sm
nlp = spacy.load("it_core_news_sm")

# %%
Text_unicode=nlp(u"Questa sera, care concittadine e cari concittadini, entriamo negli anni venti\n \ndel nuovo secolo. \n \nSi avvia a conclusione un decennio impegnativo, contrass\negnato da una lunga crisi economica e da \nmutamenti tanto veloci quanto impetuosi.\n \nIn questo tempo sono cambiate molte cose attorno a noi, nella nostra vita e nella società.\n \nDesidero,\n \nanzitutto,\n \n\nta per iniziare.\n \nSi tratta,\n \nanche,\n \n\n\n \ninsieme \n-\n \n\n \nnostre riflessioni; senza, naturalmente, trascurare il presente e i suoi problemi, ma anche rendendosi \nconto che il futuro, in realtà, è g\nià cominciato. \n \n \n \n \n \n \n \n \n \n \n\n \nVe ne sono tante sul web, ma questa mi ha fatto riflettere perché proviene da una astronauta, adesso \nal vertice di un Paese amico. \n \nVorrei condividere\n \ncon vo\ni questa immagine. \n \nCon un invito: proviamo\n \n\n \ndal di fuori, allargando lo sguardo oltre il consueto.\n \n\n \n\n \nCome vedono il nostro bel Paese, proteso nel Mediterraneo e posto, per geografia e per stor\nia, come \n\n \nQuesta condizione ha contribuito a costruire\n \nla nostra identità,\n \nsinonimo di sapienza, genio, \narmonia, umanità.\n \n\n \n\nsi apre, celebreremo Raffaello. E subito dopo\n \nrenderemo omaggio a Dante Alighieri.\n \n\n \nRegistro ovunque una grande apertura verso di noi, un forte deside\nrio di collaborazione.\n \nSimpatia\n \nnei confronti del nostro popolo. Non soltanto per il richiamo della sua arte\n \ne dei paesaggi, per la sua \ncreatività e per il suo stile di vita; ma anche per la sua politica di pace, per la ricerca\n \ne la capacità \nitaliana di di\nalogo nel rispetto reciproco, per le missioni\n \ndelle sue Forze Armate in favore della \n\ndei nostri concittadini. \n \n \nVi è una diffusa\n \ndomanda di Italia. \n \nAbbiamo problemi\n \nda non sottovalutare. \n \nIl lavoro\n \nche manca per tanti, anzitutto. Forti\n \ndiseguaglianze. Alcune\n \ngravi crisi aziendali. \n\n \nsistema produttivo. Ma abbiamo ampie possibilità\n \nper affrontare e \nrisolvere \nquesti problemi. E per svolgere inoltre\n \nun ruolo incisivo nella nostra Europa e nella intera \ncomunità\n \ninternazionale. \n \n', '\n \nQuella stessa fiducia con cui si guarda, da fuori, verso il nostro Paese\n \ndeve indurci ad averne di più \nin noi \nstessi, per dar corpo alla\n \nsperanza di un futuro migliore.\n \nConosco le difficoltà e le ferite presenti nelle\n \nnostre comunità. Le attese di\n \ntanti italiani. \n \n \nDobbiamo aver fiducia e impegnarci attivamente nel comune interesse. Disponiamo di grandi \nrisorse. D\ni umanità, di ingegno, di capacità di impresa. Tutto questo produce esperienze\n \nimportanti, \nbuone pratiche\n \ndi grande rilievo. Ne ho avuto conoscenza diretta\n \nvisitando i nostri territori. \n \n\nfare. \n \nDobbiamo\n \ncreare le condizioni\n \nche consentano\n \na tutte le risorse di cui disponiamo di emergere e di \nesprimersi senza ostacoli e difficoltà. \n \n \n \n \nCon spirito\n \ne atteggiamento di reciproca solidarietà.\n \nInsieme.\n \nIn particolar modo è necessario ridurre il \ndivario che sta ulteriormente crescendo tra Nord e Sud \n\nfrenato nelle\n \nsue potenzialità di sviluppo.\n \nNaturalmente, per promuovere fiducia, è decisivo il buon funz\nionamento delle pubbliche istituzioni \nche devono alimentarla, favorendo coesione sociale. Questo è possibile\n \nassicurando decisioni\n \nadeguate, efficaci\n \ne tempestive sui temi della vita concreta dei cittadini.\n \nLa democrazia si rafforza se le istituzioni tengo\nno viva una\n \nragionevole speranza.\n \n\n \nsviluppare, sempre di più, una cultura della\n \nresponsabilità che riguarda tutti: \ndalle formazioni politiche,\n \nai singoli cittadini, alle imprese, alle formazioni intermedie, alle \nassociazioni raccolte int\norno a interessi\n \ne a valori. \n \nLa cultura della responsabilità costituisce il più forte presidio di libertà e di difesa dei principi, su \ncui si fonda la\n \nRepubblica. Questo comune sentire\n \ndella società\n\n \nquando si esprime \n\n \nsi riflette sulle\n \nistituzioni per i\nnfondervi costantemente un autentico spirito repubblicano.\n \nLa fiducia va trasmessa ai giovani, ai quali viene sovente chiesta responsabilità, ma a cui dobbiamo \nal contempo affidare\n \nresponsabilità.\n \n \n \nLe nuove generazioni avvertono meglio degli adulti che\n \nsoltanto con una capacità di osservazione\n \npiù ampia si possono comprendere e affrontare la dimensione globale e la realtà di un mondo \nsempre più interdipendente.\n \nHanno \n\n \nad esempio \n\n \nchiara la percezione che i mutamenti climatici sono questione serissima c\nhe \nnon tollera ulteriori\n \nrinvii nel farvi fronte. \n \nLe scelte ambientali non sono\n \nsoltanto una indispensabile\n \n\n \ndelle \n\nposti di \n\n \n', 'Torniamo con il pensiero alle popolazioni delle città minacciate, come Venezia, dei territori\n \ncolpiti \ndai\n \nsismi\n \no dalle alluvioni,\n \ndelle aree inquinate, per sottolineare come il tema della t\nutela \n\n \n\nnostalgia del passato. \n \nOgni società ha sempre bisogno dei giovani. Se possibile ancor di più og\ngi\n \nche la durata della vita è \ncresciuta e gli equilibri demografici si sono spostati\n \n\n \nQuesta nuova condizione impone di predisporre nei confronti degli anziani \n\n \nparte preziosa della \nsocietà \n\n \nmaggiori cure e attenzioni. Occorre, \nal tempo stesso, investire molto sui giovani. \n \n\ncorrettamente retribuito. Favoriamo il\n \nformarsi di nuove famiglie. \n \nDobbiamo riporre fiducia nelle famiglie\n \nitaliane\n. Su di esse grava il peso maggiore degli squilibri \nsociali. Hanno affrontato i momenti più duri, superandoli. Spesso con sacrificio. \n \nFornire sostegno alle famiglie vuol dire fare in modo che possano realizzare i loro progetti di vita. E \nche i loro valori\n \n\n \n\n\n \n\nrafforzandone\n \nil senso civico.\n \n\nrispetto della cosa pubblica. \n \nArgina agg\nressività, prepotenze, meschinità, lacerazioni delle regole della convivenza.\n \nUna associazione di disabili mi ha donato per Natale una sedia. Molto semplice ma che conserverò \n\nenti, perdiamo il\n \n\n \nEsprime appieno il vero senso della convivenza.\n \n\n\n\n \nper loro e per tutte le vittime del \ndovere \n\n \nche\n \nil dolore dei familiari, dei colleghi, di tutto il Paese non può estinguersi, vorrei \n\n\nra che non voglio neppure definire. \n \n\nstoria e al sentimento profondo\n \ndella nostra gente. \n \n\n\nmunicipio ha atteso che si mettessero\n \nin salvo tutti i dipendenti, uscendone per ultimo. Sacrificando \ncosì la propria vita.\n \nSenso civico e senso della misura devono appartenere\n \nanche a chi frequenta il mondo dei social, \no\nccasione per ampliare le conoscenze, poter dialogare con tanti per esprimere le proprie idee e \nascoltare, con attenzione e rispetto, quelle degli altri. \n \n', 'Alle volte si trasforma invece in strumento per denigrare, anche deformando i fatti. \n \nSovente \nricorren\ndo a profili fittizi di soggetti inesistenti per alterare lo scambio di\n \nopinioni, per\n \ningenerare \nallarmi, per trarre vantaggio dalla diffusione di notizie false.\n \nIl mosaico che compone la società italiana ha tante tessere preziose.\n \nPenso \n\n \ntra le altre \n\n \na\nl mondo delle nostre\n \nuniversità, ai centri di ricerca, alle prestigiose istituzioni \ndella cultura. \n \nHo conosciuto e apprezzato in tante occasioni\n \n\n \nche si svolge in questa costellazione\n \ndi \n\n \nSi \ntratta di un patrimonio inestimabile di idee e di energie per costruire il futuro.\n \n\n \nessenziale che sia disponibile per tutti. \n \nChe sia conosciuto, raccontato, condiviso. Che siano rimossi gli ostacoli\n \ne reso più agevole\n \nil \n\n \nIn questo senso un ruolo fondamentale è assegnato ai media e in particolare al nostro servizio \npubblico. \n \nAbbiamo bisogno di preparazione e di competenze. \n \nOgni tanto si vede affiorare\n, invece, la tendenza a prender posizione ancor prima di informarsi.\n \nLa cultura è un grande propulsore di qualità della vita e rende il tessuto sociale di un Paese più \nsolido. \n \n\no anno in cui è stata \nCapitale della cultura\n \neuropea. \n \n \nCon questo spirito rivolgo gli auguri a Parma che, con il suo straordinario patrimonio umano e \nartistico, da domani sarà Capitale italiana della cultura per il 2020.\n \nUn saluto particolarmente grato\n \ne \nsentito rivolgo a Papa\n \nFrancesco, Vescovo di Roma, che esercita \nil suo alto magistero con saggezza e coraggio e che mostra ogni giorno\n \ndi amare il nostro Paese, a \npartire da coloro che versano in condizioni di bisogno e da chi, praticando solidarietà, reca\n \nbeneficio\n \n\n \ncomunità civile.\n \n\nquanti il nostro Paese ospita, vorrei rivolgere un saluto particolare a coloro che, in queste giornate \nfestive\n, assicurano \n\n \ncome sempre \n\n \nil funzionamento dei servizi necessari alla nostra vita comune.\n \n\ncoloro che, con vari ruoli\n \ne compiti, operano a beneficio della Re\npubblica e di tutti noi cittadini.\n \nPer tutti, saluto Luca Parmitano \n\n \nil primo astronauta italiano\n \nal comando della stazione spaziale \ninternazionale \n\n \n\n \nprincipali protago\nnisti.\n \n', 'Da lassù, da quella navicella \n\n \ncome mi ha detto\n \nquando ci siamo collegati \n\n \navverte quanto\n \nappaiano incomprensibili e dissennate le\n \ninimicizie, le contrapposizioni e le violenze in un pianeta\n \nsempre più piccolo e raccolto.\n \nE mi ha trasmesso un mess\naggio\n \nche faccio mio: la speranza consiste nella possibilità di avere \nsempre qualcosa da raggiungere. \n \n\n \nche rivolgo\n \na tutti voi !\n \nBuon 2020 !")

# %%
type(Text_unicode)
# Out:
# spacy.tokens.doc.Doc

# %%
#isolate punctuation
for t in Text_unicode:
    print(t)
# Out:
# Questa
# sera
# ,
# care
# concittadine
# e
# cari
# concittadini
# ,
# entriamo
# negli
# anni
# venti
#
#
#
# del
# nuovo
# secolo
# .
#
#
#
# Si
# avvia
# a
# conclusione
# un
# decennio
# impegnativo
# ,
# contrass
#
#
# egnato
# da
# una
# lunga
# crisi
# economica
# e
# da
#
#
# mutamenti
# tanto
# veloci
# quanto
# impetuosi
# .
#
#
#
# In
# questo
# tempo
# sono
# cambiate
# molte
# cose
# attorno
# a
# noi
# ,
# nella
# nostra
# vita
# e
# nella
# società
# .
#
#
#
# Desidero
# ,
#
#
#
# anzitutto
# ,
#
#
#
#
# ta
# per
# iniziare
# .
#
#
#
# Si
# tratta
# ,
#
#
#
# anche
# ,
#
#
#
#
#
#
# insieme
#
#
# -
#
#
#
#
#
# nostre
# riflessioni
# ;
# senza
# ,
# naturalmente
# ,
# trascurare
# il
# presente
# e
# i
# suoi
# problemi
# ,
# ma
# anche
# rendendosi
#
#
# conto
# che
# il
# futuro
# ,
# in
# realtà
# ,
# è
# g
#
#
# ià
# cominciato
# .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Ve
# ne
# sono
# tante
# sul
# web
# ,
# ma
# questa
# mi
# ha
# fatto
# riflettere
# perché
# proviene
# da
# una
# astronauta
# ,
# adesso
#
#
# al
# vertice
# di
# un
# Paese
# amico
# .
#
#
#
# Vorrei
# condividere
#
#
#
# con
# vo
#
#
# i
# questa
# immagine
# .
#
#
#
# Con
# un
# invito
# :
# proviamo
#
#
#
#
#
# dal
# di
# fuori
# ,
# allargando
# lo
# sguardo
# oltre
# il
# consueto
# .
#
#
#
#
#
#
#
# Come
# vedono
# il
# nostro
# bel
# Paese
# ,
# proteso
# nel
# Mediterraneo
# e
# posto
# ,
# per
# geografia
# e
# per
# stor
#
#
# ia
# ,
# come
#
#
#
#
# Questa
# condizione
# ha
# contribuito
# a
# costruire
#
#
#
# la
# nostra
# identità
# ,
#
#
#
# sinonimo
# di
# sapienza
# ,
# genio
# ,
#
#
# armonia
# ,
# umanità
# .
#
#
#
#
#
#
# si
# apre
# ,
# celebreremo
# Raffaello
# .
# E
# subito
# dopo
#
#
#
# renderemo
# omaggio
# a
# Dante
# Alighieri
# .
#
#
#
#
#
# Registro
# ovunque
# una
# grande
# apertura
# verso
# di
# noi
# ,
# un
# forte
# deside
#
#
# rio
# di
# collaborazione
# .
#
#
#
# Simpatia
#
#
#
# nei
# confronti
# del
# nostro
# popolo
# .
# Non
# soltanto
# per
# il
# richiamo
# della
# sua
# arte
#
#
#
# e
# dei
# paesaggi
# ,
# per
# la
# sua
#
#
# creatività
# e
# per
# il
# suo
# stile
# di
# vita
# ;
# ma
# anche
# per
# la
# sua
# politica
# di
# pace
# ,
# per
# la
# ricerca
#
#
#
# e
# la
# capacità
#
#
# italiana
# di
# di
#
#
# alogo
# nel
# rispetto
# reciproco
# ,
# per
# le
# missioni
#
#
#
# delle
# sue
# Forze
# Armate
# in
# favore
# della
#
#
#
# dei
# nostri
# concittadini
# .
#
#
#
#
# Vi
# è
# una
# diffusa
#
#
#
# domanda
# di
# Italia
# .
#
#
#
# Abbiamo
# problemi
#
#
#
# da
# non
# sottovalutare
# .
#
#
#
# Il
# lavoro
#
#
#
# che
# manca
# per
# tanti
# ,
# anzitutto
# .
# Forti
#
#
#
# diseguaglianze
# .
# Alcune
#
#
#
# gravi
# crisi
# aziendali
# .
#
#
#
#
# sistema
# produttivo
# .
# Ma
# abbiamo
# ampie
# possibilità
#
#
#
# per
# affrontare
# e
#
#
# risolvere
#
#
# questi
# problemi
# .
# E
# per
# svolgere
# inoltre
#
#
#
# un
# ruolo
# incisivo
# nella
# nostra
# Europa
# e
# nella
# intera
#
#
# comunità
#
#
#
# internazionale
# .
#
#
#
# '
# ,
# '
#
#
#
# Quella
# stessa
# fiducia
# con
# cui
# si
# guarda
# ,
# da
# fuori
# ,
# verso
# il
# nostro
# Paese
#
#
#
# deve
# indurci
# ad
# averne
# di
# più
#
#
# in
# noi
#
#
# stessi
# ,
# per
# dar
# corpo
# alla
#
#
#
# speranza
# di
# un
# futuro
# migliore
# .
#
#
#
# Conosco
# le
# difficoltà
# e
# le
# ferite
# presenti
# nelle
#
#
#
# nostre
# comunità
# .
# Le
# attese
# di
#
#
#
# tanti
# italiani
# .
#
#
#
#
# Dobbiamo
# aver
# fiducia
# e
# impegnarci
# attivamente
# nel
# comune
# interesse
# .
# Disponiamo
# di
# grandi
#
#
# risorse
# .
# D
#
#
# i
# umanità
# ,
# di
# ingegno
# ,
# di
# capacità
# di
# impresa
# .
# Tutto
# questo
# produce
# esperienze
#
#
#
# importanti
# ,
#
#
# buone
# pratiche
#
#
#
# di
# grande
# rilievo
# .
# Ne
# ho
# avuto
# conoscenza
# diretta
#
#
#
# visitando
# i
# nostri
# territori
# .
#
#
#
#
# fare
# .
#
#
#
# Dobbiamo
#
#
#
# creare
# le
# condizioni
#
#
#
# che
# consentano
#
#
#
# a
# tutte
# le
# risorse
# di
# cui
# disponiamo
# di
# emergere
# e
# di
#
#
# esprimersi
# senza
# ostacoli
# e
# difficoltà
# .
#
#
#
#
#
#
# Con
# spirito
#
#
#
# e
# atteggiamento
# di
# reciproca
# solidarietà
# .
#
#
#
# Insieme
# .
#
#
#
# In
# particolar
# modo
# è
# necessario
# ridurre
# il
#
#
# divario
# che
# sta
# ulteriormente
# crescendo
# tra
# Nord
# e
# Sud
#
#
#
# frenato
# nelle
#
#
#
# sue
# potenzialità
# di
# sviluppo
# .
#
#
#
# Naturalmente
# ,
# per
# promuovere
# fiducia
# ,
# è
# decisivo
# il
# buon
# funz
#
#
# ionamento
# delle
# pubbliche
# istituzioni
#
#
# che
# devono
# alimentarla
# ,
# favorendo
# coesione
# sociale
# .
# Questo
# è
# possibile
#
#
#
# assicurando
# decisioni
#
#
#
# adeguate
# ,
# efficaci
#
#
#
# e
# tempestive
# sui
# temi
# della
# vita
# concreta
# dei
# cittadini
# .
#
#
#
# La
# democrazia
# si
# rafforza
# se
# le
# istituzioni
# tengo
#
#
# no
# viva
# una
#
#
#
# ragionevole
# speranza
# .
#
#
#
#
#
# sviluppare
# ,
# sempre
# di
# più
# ,
# una
# cultura
# della
#
#
#
# responsabilità
# che
# riguarda
# tutti
# :
#
#
# dalle
# formazioni
# politiche
# ,
#
#
#
# ai
# singoli
# cittadini
# ,
# alle
# imprese
# ,
# alle
# formazioni
# intermedie
# ,
# alle
#
#
# associazioni
# raccolte
# int
#
#
# orno
# a
# interessi
#
#
#
# e
# a
# valori
# .
#
#
#
# La
# cultura
# della
# responsabilità
# costituisce
# il
# più
# forte
# presidio
# di
# libertà
# e
# di
# difesa
# dei
# principi
# ,
# su
#
#
# cui
# si
# fonda
# la
#
#
#
# Repubblica
# .
# Questo
# comune
# sentire
#
#
#
# della
# società
#
#
#
#
# quando
# si
# esprime
#
#
#
#
# si
# riflette
# sulle
#
#
#
# istituzioni
# per
# i
#
#
# nfondervi
# costantemente
# un
# autentico
# spirito
# repubblicano
# .
#
#
#
# La
# fiducia
# va
# trasmessa
# ai
# giovani
# ,
# ai
# quali
# viene
# sovente
# chiesta
# responsabilità
# ,
# ma
# a
# cui
# dobbiamo
#
#
# al
# contempo
# affidare
#
#
#
# responsabilità
# .
#
#
#
#
#
# Le
# nuove
# generazioni
# avvertono
# meglio
# degli
# adulti
# che
#
#
#
# soltanto
# con
# una
# capacità
# di
# osservazione
#
#
#
# più
# ampia
# si
# possono
# comprendere
# e
# affrontare
# la
# dimensione
# globale
# e
# la
# realtà
# di
# un
# mondo
#
#
# sempre
# più
# interdipendente
# .
#
#
#
# Hanno
#
#
#
#
# ad
# esempio
#
#
#
#
# chiara
# la
# percezione
# che
# i
# mutamenti
# climatici
# sono
# questione
# serissima
# c
#
#
# he
#
#
# non
# tollera
# ulteriori
#
#
#
# rinvii
# nel
# farvi
# fronte
# .
#
#
#
# Le
# scelte
# ambientali
# non
# sono
#
#
#
# soltanto
# una
# indispensabile
#
#
#
#
#
# delle
#
#
#
# posti
# di
#
#
#
#
# '
# ,
# '
# Torniamo
# con
# il
# pensiero
# alle
# popolazioni
# delle
# città
# minacciate
# ,
# come
# Venezia
# ,
# dei
# territori
#
#
#
# colpiti
#
#
# dai
#
#
#
# sismi
#
#
#
# o
# dalle
# alluvioni
# ,
#
#
#
# delle
# aree
# inquinate
# ,
# per
# sottolineare
# come
# il
# tema
# della
# t
#
#
# utela
#
#
#
#
#
# nostalgia
# del
# passato
# .
#
#
#
# Ogni
# società
# ha
# sempre
# bisogno
# dei
# giovani
# .
# Se
# possibile
# ancor
# di
# più
# og
#
#
# gi
#
#
#
# che
# la
# durata
# della
# vita
# è
#
#
# cresciuta
# e
# gli
# equilibri
# demografici
# si
# sono
# spostati
#
#
#
#
#
# Questa
# nuova
# condizione
# impone
# di
# predisporre
# nei
# confronti
# degli
# anziani
#
#
#
#
# parte
# preziosa
# della
#
#
# società
#
#
#
#
# maggiori
# cure
# e
# attenzioni
# .
# Occorre
# ,
#
#
# al
# tempo
# stesso
# ,
# investire
# molto
# sui
# giovani
# .
#
#
#
#
# correttamente
# retribuito
# .
# Favoriamo
# il
#
#
#
# formarsi
# di
# nuove
# famiglie
# .
#
#
#
# Dobbiamo
# riporre
# fiducia
# nelle
# famiglie
#
#
#
# italiane
#
#
# .
# Su
# di
# esse
# grava
# il
# peso
# maggiore
# degli
# squilibri
#
#
# sociali
# .
# Hanno
# affrontato
# i
# momenti
# più
# duri
# ,
# superandoli
# .
# Spesso
# con
# sacrificio
# .
#
#
#
# Fornire
# sostegno
# alle
# famiglie
# vuol
# dire
# fare
# in
# modo
# che
# possano
# realizzare
# i
# loro
# progetti
# di
# vita
# .
# E
#
#
# che
# i
# loro
# valori
#
#
#
#
#
#
#
#
#
# rafforzandone
#
#
#
# il
# senso
# civico
# .
#
#
#
#
# rispetto
# della
# cosa
# pubblica
# .
#
#
#
# Argina
# agg
#
#
# ressività
# ,
# prepotenze
# ,
# meschinità
# ,
# lacerazioni
# delle
# regole
# della
# convivenza
# .
#
#
#
# Una
# associazione
# di
# disabili
# mi
# ha
# donato
# per
# Natale
# una
# sedia
# .
# Molto
# semplice
# ma
# che
# conserverò
#
#
#
# enti
# ,
# perdiamo
# il
#
#
#
#
#
# Esprime
# appieno
# il
# vero
# senso
# della
# convivenza
# .
#
#
#
#
#
#
#
# per
# loro
# e
# per
# tutte
# le
# vittime
# del
#
#
# dovere
#
#
#
#
# che
#
#
#
# il
# dolore
# dei
# familiari
# ,
# dei
# colleghi
# ,
# di
# tutto
# il
# Paese
# non
# può
# estinguersi
# ,
# vorrei
#
#
#
#
# ra
# che
# non
# voglio
# neppure
# definire
# .
#
#
#
#
# storia
# e
# al
# sentimento
# profondo
#
#
#
# della
# nostra
# gente
# .
#
#
#
#
#
# municipio
# ha
# atteso
# che
# si
# mettessero
#
#
#
# in
# salvo
# tutti
# i
# dipendenti
# ,
# uscendone
# per
# ultimo
# .
# Sacrificando
#
#
# così
# la
# propria
# vita
# .
#
#
#
# Senso
# civico
# e
# senso
# della
# misura
# devono
# appartenere
#
#
#
# anche
# a
# chi
# frequenta
# il
# mondo
# dei
# social
# ,
#
#
# o
#
#
# ccasione
# per
# ampliare
# le
# conoscenze
# ,
# poter
# dialogare
# con
# tanti
# per
# esprimere
# le
# proprie
# idee
# e
#
#
# ascoltare
# ,
# con
# attenzione
# e
# rispetto
# ,
# quelle
# degli
# altri
# .
#
#
#
# '
# ,
# '
# Alle
# volte
# si
# trasforma
# invece
# in
# strumento
# per
# denigrare
# ,
# anche
# deformando
# i
# fatti
# .
#
#
#
# Sovente
#
#
# ricorren
#
#
# do
# a
# profili
# fittizi
# di
# soggetti
# inesistenti
# per
# alterare
# lo
# scambio
# di
#
#
#
# opinioni
# ,
# per
#
#
#
# ingenerare
#
#
# allarmi
# ,
# per
# trarre
# vantaggio
# dalla
# diffusione
# di
# notizie
# false
# .
#
#
#
# Il
# mosaico
# che
# compone
# la
# società
# italiana
# ha
# tante
# tessere
# preziose
# .
#
#
#
# Penso
#
#
#
#
# tra
# le
# altre
#
#
#
#
# a
#
#
# l
# mondo
# delle
# nostre
#
#
#
# università
# ,
# ai
# centri
# di
# ricerca
# ,
# alle
# prestigiose
# istituzioni
#
#
# della
# cultura
# .
#
#
#
# Ho
# conosciuto
# e
# apprezzato
# in
# tante
# occasioni
#
#
#
#
#
# che
# si
# svolge
# in
# questa
# costellazione
#
#
#
# di
#
#
#
#
# Si
#
#
# tratta
# di
# un
# patrimonio
# inestimabile
# di
# idee
# e
# di
# energie
# per
# costruire
# il
# futuro
# .
#
#
#
#
#
# essenziale
# che
# sia
# disponibile
# per
# tutti
# .
#
#
#
# Che
# sia
# conosciuto
# ,
# raccontato
# ,
# condiviso
# .
# Che
# siano
# rimossi
# gli
# ostacoli
#
#
#
# e
# reso
# più
# agevole
#
#
#
# il
#
#
#
#
# In
# questo
# senso
# un
# ruolo
# fondamentale
# è
# assegnato
# ai
# media
# e
# in
# particolare
# al
# nostro
# servizio
#
#
# pubblico
# .
#
#
#
# Abbiamo
# bisogno
# di
# preparazione
# e
# di
# competenze
# .
#
#
#
# Ogni
# tanto
# si
# vede
# affiorare
#
#
# ,
# invece
# ,
# la
# tendenza
# a
# prender
# posizione
# ancor
# prima
# di
# informarsi
# .
#
#
#
# La
# cultura
# è
# un
# grande
# propulsore
# di
# qualità
# della
# vita
# e
# rende
# il
# tessuto
# sociale
# di
# un
# Paese
# più
#
#
# solido
# .
#
#
#
#
# o
# anno
# in
# cui
# è
# stata
#
#
# Capitale
# della
# cultura
#
#
#
# europea
# .
#
#
#
#
# Con
# questo
# spirito
# rivolgo
# gli
# auguri
# a
# Parma
# che
# ,
# con
# il
# suo
# straordinario
# patrimonio
# umano
# e
#
#
# artistico
# ,
# da
# domani
# sarà
# Capitale
# italiana
# della
# cultura
# per
# il
# 2020
# .
#
#
#
# Un
# saluto
# particolarmente
# grato
#
#
#
# e
#
#
# sentito
# rivolgo
# a
# Papa
#
#
#
# Francesco
# ,
# Vescovo
# di
# Roma
# ,
# che
# esercita
#
#
# il
# suo
# alto
# magistero
# con
# saggezza
# e
# coraggio
# e
# che
# mostra
# ogni
# giorno
#
#
#
# di
# amare
# il
# nostro
# Paese
# ,
# a
#
#
# partire
# da
# coloro
# che
# versano
# in
# condizioni
# di
# bisogno
# e
# da
# chi
# ,
# praticando
# solidarietà
# ,
# reca
#
#
#
# beneficio
#
#
#
#
#
# comunità
# civile
# .
#
#
#
#
# quanti
# il
# nostro
# Paese
# ospita
# ,
# vorrei
# rivolgere
# un
# saluto
# particolare
# a
# coloro
# che
# ,
# in
# queste
# giornate
#
#
# festive
#
#
# ,
# assicurano
#
#
#
#
# come
# sempre
#
#
#
#
# il
# funzionamento
# dei
# servizi
# necessari
# alla
# nostra
# vita
# comune
# .
#
#
#
#
# coloro
# che
# ,
# con
# vari
# ruoli
#
#
#
# e
# compiti
# ,
# operano
# a
# beneficio
# della
# Re
#
#
# pubblica
# e
# di
# tutti
# noi
# cittadini
# .
#
#
#
# Per
# tutti
# ,
# saluto
# Luca
# Parmitano
#
#
#
#
# il
# primo
# astronauta
# italiano
#
#
#
# al
# comando
# della
# stazione
# spaziale
#
#
# internazionale
#
#
#
#
#
#
# principali
# protago
#
#
# nisti
# .
#
#
#
# '
# ,
# '
# Da
# lassù
# ,
# da
# quella
# navicella
#
#
#
#
# come
# mi
# ha
# detto
#
#
#
# quando
# ci
# siamo
# collegati
#
#
#
#
# avverte
# quanto
#
#
#
# appaiano
# incomprensibili
# e
# dissennate
# le
#
#
#
# inimicizie
# ,
# le
# contrapposizioni
# e
# le
# violenze
# in
# un
# pianeta
#
#
#
# sempre
# più
# piccolo
# e
# raccolto
# .
#
#
#
# E
# mi
# ha
# trasmesso
# un
# mess
#
#
# aggio
#
#
#
# che
# faccio
# mio
# :
# la
# speranza
# consiste
# nella
# possibilità
# di
# avere
#
#
# sempre
# qualcosa
# da
# raggiungere
# .
#
#
#
#
#
# che
# rivolgo
#
#
#
# a
# tutti
# voi
# !
#
#
#
# Buon
# 2020
# !

# %%
from nltk.corpus import stopwords
from stop_words import get_stop_words
stop_words = get_stop_words('italian')

# %%
# Add the word to the set of stop words. Use lowercase!
nlp.Defaults.stop_words.add('e')
nlp.vocab['e'].is_stop = True
nlp.Defaults.stop_words.add('.')
nlp.vocab['.'].is_stop = True
nlp.Defaults.stop_words.add(',')
nlp.vocab[','].is_stop = True
nlp.Defaults.stop_words.add(' ')
nlp.vocab[' '].is_stop = True
nlp.Defaults.stop_words.add('-')
nlp.vocab['-'].is_stop = True
nlp.Defaults.stop_words.add(':')
nlp.vocab[':'].is_stop = True
nlp.Defaults.stop_words.add(';')
nlp.vocab[';'].is_stop = True

# %%
token_list = []
for token in Text_unicode:
    token_list.append(token.text)

# %%
filtered_sentence =[] 
for word in token_list:
    lexeme = nlp.vocab[word]
    if lexeme.is_stop == False:
        filtered_sentence.append(word) 
# print(token_list)
print(filtered_sentence)
# Out:
# ['sera', 'care', 'concittadine', 'cari', 'concittadini', 'entriamo', 'venti', '\n \n', 'secolo', '\n \n', 'avvia', 'decennio', 'impegnativo', 'contrass', '\n', 'egnato', 'lunga', 'crisi', 'economica', '\n', 'mutamenti', 'veloci', 'impetuosi', '\n \n', 'cambiate', 'molte', 'cose', 'attorno', 'società', '\n \n', 'Desidero', '\n \n', 'anzitutto', '\n \n\n', 'ta', 'iniziare', '\n \n', 'tratta', '\n \n', '\n \n\n\n \n', '\n', '\n \n\n \n', 'riflessioni', 'naturalmente', 'trascurare', 'presente', 'i', 'problemi', 'rendendosi', '\n', 'conto', 'realtà', 'è', 'g', '\n', 'ià', 'cominciato', '\n \n \n \n \n \n \n \n \n \n \n\n \n', 'Ve', 'tante', 'web', 'riflettere', 'proviene', 'astronauta', '\n', 'vertice', 'amico', '\n \n', 'Vorrei', 'condividere', '\n \n', 'vo', '\n', 'i', 'immagine', '\n \n', 'invito', 'proviamo', '\n \n\n \n', 'allargando', 'sguardo', 'consueto', '\n \n\n \n\n \n', 'vedono', 'bel', 'proteso', 'Mediterraneo', 'geografia', 'stor', '\n', 'ia', '\n\n \n', 'condizione', 'contribuito', 'costruire', '\n \n', 'identità', '\n \n', 'sinonimo', 'sapienza', 'genio', '\n', 'armonia', 'umanità', '\n \n\n \n\n', 'apre', 'celebreremo', 'Raffaello', 'E', '\n \n', 'renderemo', 'omaggio', 'Dante', 'Alighieri', '\n \n\n \n', 'Registro', 'ovunque', 'apertura', 'forte', 'deside', '\n', 'rio', 'collaborazione', '\n \n', 'Simpatia', '\n \n', 'confronti', 'popolo', 'richiamo', 'arte', '\n \n', 'paesaggi', '\n', 'creatività', 'stile', 'politica', 'pace', 'ricerca', '\n \n', 'capacità', '\n', 'italiana', '\n', 'alogo', 'rispetto', 'reciproco', 'missioni', '\n \n', 'Forze', 'Armate', '\n\n', 'concittadini', '\n \n \n', 'è', 'diffusa', '\n \n', 'domanda', 'Italia', '\n \n', 'problemi', '\n \n', 'sottovalutare', '\n \n', '\n \n', 'manca', 'tanti', 'anzitutto', 'Forti', '\n \n', 'diseguaglianze', 'Alcune', '\n \n', 'gravi', 'crisi', 'aziendali', '\n\n \n', 'sistema', 'produttivo', 'ampie', 'possibilità', '\n \n', 'affrontare', '\n', 'risolvere', '\n', 'problemi', 'E', 'svolgere', '\n \n', 'ruolo', 'incisivo', 'Europa', 'intera', '\n', 'comunità', '\n \n', 'internazionale', '\n \n', "'", "'", '\n \n', 'fiducia', 'guarda', '\n \n', 'indurci', 'averne', '\n', '\n', 'dar', 'corpo', '\n \n', 'speranza', 'migliore', '\n \n', 'Conosco', 'difficoltà', 'ferite', 'presenti', '\n \n', 'comunità', 'attese', '\n \n', 'tanti', 'italiani', '\n \n \n', 'Dobbiamo', 'fiducia', 'impegnarci', 'attivamente', 'comune', 'interesse', 'Disponiamo', 'grandi', '\n', 'risorse', 'D', '\n', 'i', 'umanità', 'ingegno', 'capacità', 'impresa', 'produce', 'esperienze', '\n \n', 'importanti', '\n', 'buone', 'pratiche', '\n \n', 'rilievo', 'conoscenza', 'diretta', '\n \n', 'visitando', 'i', 'territori', '\n \n\n', '\n \n', 'Dobbiamo', '\n \n', 'creare', 'condizioni', '\n \n', 'consentano', '\n \n', 'risorse', 'disponiamo', 'emergere', '\n', 'esprimersi', 'ostacoli', 'difficoltà', '\n \n \n \n \n', 'spirito', '\n \n', 'atteggiamento', 'reciproca', 'solidarietà', '\n \n', '\n \n', 'particolar', 'è', 'necessario', 'ridurre', '\n', 'divario', 'ulteriormente', 'crescendo', 'Nord', 'Sud', '\n\n', 'frenato', '\n \n', 'potenzialità', 'sviluppo', '\n \n', 'Naturalmente', 'promuovere', 'fiducia', 'è', 'decisivo', 'buon', 'funz', '\n', 'ionamento', 'pubbliche', 'istituzioni', '\n', 'devono', 'alimentarla', 'favorendo', 'coesione', 'sociale', 'è', 'possibile', '\n \n', 'assicurando', 'decisioni', '\n \n', 'adeguate', 'efficaci', '\n \n', 'tempestive', 'temi', 'concreta', 'cittadini', '\n \n', 'democrazia', 'rafforza', 'istituzioni', 'tengo', '\n', 'viva', '\n \n', 'ragionevole', 'speranza', '\n \n\n \n', 'sviluppare', 'cultura', '\n \n', 'responsabilità', 'riguarda', '\n', 'formazioni', 'politiche', '\n \n', 'singoli', 'cittadini', 'imprese', 'formazioni', 'intermedie', '\n', 'associazioni', 'raccolte', 'int', '\n', 'orno', 'interessi', '\n \n', 'valori', '\n \n', 'cultura', 'responsabilità', 'costituisce', 'forte', 'presidio', 'libertà', 'difesa', 'principi', '\n', 'fonda', '\n \n', 'Repubbli ...

# %%
type(filtered_sentence)
# Out:
# list

# %%
# remove \n and empty string 
resul = map(str.rstrip, filtered_sentence)
str_list = filter(None, list(resul))
print(list(str_list))
# Out:
# ['sera', 'care', 'concittadine', 'cari', 'concittadini', 'entriamo', 'venti', 'secolo', 'avvia', 'decennio', 'impegnativo', 'contrass', 'egnato', 'lunga', 'crisi', 'economica', 'mutamenti', 'veloci', 'impetuosi', 'cambiate', 'molte', 'cose', 'attorno', 'società', 'Desidero', 'anzitutto', 'ta', 'iniziare', 'tratta', 'riflessioni', 'naturalmente', 'trascurare', 'presente', 'i', 'problemi', 'rendendosi', 'conto', 'realtà', 'è', 'g', 'ià', 'cominciato', 'Ve', 'tante', 'web', 'riflettere', 'proviene', 'astronauta', 'vertice', 'amico', 'Vorrei', 'condividere', 'vo', 'i', 'immagine', 'invito', 'proviamo', 'allargando', 'sguardo', 'consueto', 'vedono', 'bel', 'proteso', 'Mediterraneo', 'geografia', 'stor', 'ia', 'condizione', 'contribuito', 'costruire', 'identità', 'sinonimo', 'sapienza', 'genio', 'armonia', 'umanità', 'apre', 'celebreremo', 'Raffaello', 'E', 'renderemo', 'omaggio', 'Dante', 'Alighieri', 'Registro', 'ovunque', 'apertura', 'forte', 'deside', 'rio', 'collaborazione', 'Simpatia', 'confronti', 'popolo', 'richiamo', 'arte', 'paesaggi', 'creatività', 'stile', 'politica', 'pace', 'ricerca', 'capacità', 'italiana', 'alogo', 'rispetto', 'reciproco', 'missioni', 'Forze', 'Armate', 'concittadini', 'è', 'diffusa', 'domanda', 'Italia', 'problemi', 'sottovalutare', 'manca', 'tanti', 'anzitutto', 'Forti', 'diseguaglianze', 'Alcune', 'gravi', 'crisi', 'aziendali', 'sistema', 'produttivo', 'ampie', 'possibilità', 'affrontare', 'risolvere', 'problemi', 'E', 'svolgere', 'ruolo', 'incisivo', 'Europa', 'intera', 'comunità', 'internazionale', "'", "'", 'fiducia', 'guarda', 'indurci', 'averne', 'dar', 'corpo', 'speranza', 'migliore', 'Conosco', 'difficoltà', 'ferite', 'presenti', 'comunità', 'attese', 'tanti', 'italiani', 'Dobbiamo', 'fiducia', 'impegnarci', 'attivamente', 'comune', 'interesse', 'Disponiamo', 'grandi', 'risorse', 'D', 'i', 'umanità', 'ingegno', 'capacità', 'impresa', 'produce', 'esperienze', 'importanti', 'buone', 'pratiche', 'rilievo', 'conoscenza', 'diretta', 'visitando', 'i', 'territori', 'Dobbiamo', 'creare', 'condizioni', 'consentano', 'risorse', 'disponiamo', 'emergere', 'esprimersi', 'ostacoli', 'difficoltà', 'spirito', 'atteggiamento', 'reciproca', 'solidarietà', 'particolar', 'è', 'necessario', 'ridurre', 'divario', 'ulteriormente', 'crescendo', 'Nord', 'Sud', 'frenato', 'potenzialità', 'sviluppo', 'Naturalmente', 'promuovere', 'fiducia', 'è', 'decisivo', 'buon', 'funz', 'ionamento', 'pubbliche', 'istituzioni', 'devono', 'alimentarla', 'favorendo', 'coesione', 'sociale', 'è', 'possibile', 'assicurando', 'decisioni', 'adeguate', 'efficaci', 'tempestive', 'temi', 'concreta', 'cittadini', 'democrazia', 'rafforza', 'istituzioni', 'tengo', 'viva', 'ragionevole', 'speranza', 'sviluppare', 'cultura', 'responsabilità', 'riguarda', 'formazioni', 'politiche', 'singoli', 'cittadini', 'imprese', 'formazioni', 'intermedie', 'associazioni', 'raccolte', 'int', 'orno', 'interessi', 'valori', 'cultura', 'responsabilità', 'costituisce', 'forte', 'presidio', 'libertà', 'difesa', 'principi', 'fonda', 'Repubblica', 'comune', 'sentire', 'società', 'esprime', 'riflette', 'istituzioni', 'i', 'nfondervi', 'costantemente', 'autentico', 'spirito', 'repubblicano', 'fiducia', 'trasmessa', 'giovani', 'viene', 'sovente', 'chiesta', 'responsabilità', 'dobbiamo', 'contempo', 'affidare', 'responsabilità', 'nuove', 'generazioni', 'avvertono', 'adulti', 'capacità', 'osservazione', 'ampia', 'possono', 'comprendere', 'affrontare', 'dimensione', 'globale', 'realtà', 'interdipendente', 'chiara', 'percezione', 'i', 'mutamenti', 'climatici', 'questione', 'serissima', 'c', 'he', 'tollera', 'ulteriori', 'rinvii', 'farvi', 'fronte', 'scelte', 'ambientali', 'indispensabile', 'posti', "'", "'", 'Torniamo', 'pensiero', 'popolazioni', 'minacciate', 'Venezia', 'territori', 'colpiti', 'sismi', 'o', 'alluvioni', 'aree', 'inquinate', 'sottolineare', 'tema', 't', 'utela', 'nostalgia', 'passato', 'società', 'bisogno', 'giovani', 'possibile', 'ancor', 'og', 'gi', 'durat ...

# %%
type(str_list)
# Out:
# filter

# %%
Text_list=['sera', 'care', 'concittadine', 'cari', 'concittadini', 'entriamo', 'venti', 'secolo', 'avvia', 'decennio', 'impegnativo', 'contrass', 'egnato', 'lunga', 'crisi', 'economica', 'mutamenti', 'veloci', 'impetuosi', 'cambiate', 'molte', 'cose', 'attorno', 'società', 'Desidero', 'anzitutto', 'ta', 'iniziare', 'tratta', 'riflessioni', 'naturalmente', 'trascurare', 'presente', 'i', 'problemi', 'rendendosi', 'conto', 'realtà', 'è', 'g', 'ià', 'cominciato', 'Ve', 'tante', 'web', 'riflettere', 'proviene', 'astronauta', 'vertice', 'amico', 'Vorrei', 'condividere', 'vo', 'i', 'immagine', 'invito', 'proviamo', 'allargando', 'sguardo', 'consueto', 'vedono', 'bel', 'proteso', 'Mediterraneo', 'geografia', 'stor', 'ia', 'condizione', 'contribuito', 'costruire', 'identità', 'sinonimo', 'sapienza', 'genio', 'armonia', 'umanità', 'apre', 'celebreremo', 'Raffaello', 'renderemo', 'omaggio', 'Dante', 'Alighieri', 'Registro', 'ovunque', 'apertura', 'forte', 'deside', 'rio', 'collaborazione', 'Simpatia', 'confronti', 'popolo', 'richiamo', 'arte', 'paesaggi', 'creatività', 'stile', 'politica', 'pace', 'ricerca', 'capacità', 'italiana', 'alogo', 'rispetto', 'reciproco', 'missioni', 'Forze', 'Armate', 'concittadini', 'è', 'diffusa', 'domanda', 'Italia', 'problemi', 'sottovalutare', 'manca', 'tanti', 'anzitutto', 'Forti', 'diseguaglianze', 'Alcune', 'gravi', 'crisi', 'aziendali', 'sistema', 'produttivo', 'ampie', 'possibilità', 'affrontare', 'risolvere', 'problemi', 'svolgere', 'ruolo', 'incisivo', 'Europa', 'intera', 'comunità', 'internazionale', "'", "'", 'fiducia', 'guarda', 'indurci', 'averne', 'dar', 'corpo', 'speranza', 'migliore', 'Conosco', 'difficoltà', 'ferite', 'presenti', 'comunità', 'attese', 'tanti', 'italiani', 'Dobbiamo', 'fiducia', 'impegnarci', 'attivamente', 'comune', 'interesse', 'Disponiamo', 'grandi', 'risorse', 'D', 'i', 'umanità', 'ingegno', 'capacità', 'impresa', 'produce', 'esperienze', 'importanti', 'buone', 'pratiche', 'rilievo', 'conoscenza', 'diretta', 'visitando', 'i', 'territori', 'Dobbiamo', 'creare', 'condizioni', 'consentano', 'risorse', 'disponiamo', 'emergere', 'esprimersi', 'ostacoli', 'difficoltà', 'spirito', 'atteggiamento', 'reciproca', 'solidarietà', 'particolar', 'è', 'necessario', 'ridurre', 'divario', 'ulteriormente', 'crescendo', 'Nord', 'Sud', 'frenato', 'potenzialità', 'sviluppo', 'Naturalmente', 'promuovere', 'fiducia', 'è', 'decisivo', 'buon', 'funz', 'ionamento', 'pubbliche', 'istituzioni', 'devono', 'alimentarla', 'favorendo', 'coesione', 'sociale', 'è', 'possibile', 'assicurando', 'decisioni', 'adeguate', 'efficaci', 'tempestive', 'temi', 'concreta', 'cittadini', 'democrazia', 'rafforza', 'istituzioni', 'tengo', 'viva', 'ragionevole', 'speranza', 'sviluppare', 'cultura', 'responsabilità', 'riguarda', 'formazioni', 'politiche', 'singoli', 'cittadini', 'imprese', 'formazioni', 'intermedie', 'associazioni', 'raccolte', 'int', 'orno', 'interessi', 'valori', 'cultura', 'responsabilità', 'costituisce', 'forte', 'presidio', 'libertà', 'difesa', 'principi', 'fonda', 'Repubblica', 'comune', 'sentire', 'società', 'esprime', 'riflette', 'istituzioni', 'i', 'nfondervi', 'costantemente', 'autentico', 'spirito', 'repubblicano', 'fiducia', 'trasmessa', 'giovani', 'viene', 'sovente', 'chiesta', 'responsabilità', 'dobbiamo', 'contempo', 'affidare', 'responsabilità', 'nuove', 'generazioni', 'avvertono', 'adulti', 'capacità', 'osservazione', 'ampia', 'possono', 'comprendere', 'affrontare', 'dimensione', 'globale', 'realtà', 'interdipendente', 'chiara', 'percezione', 'i', 'mutamenti', 'climatici', 'questione', 'serissima', 'c', 'he', 'tollera', 'ulteriori', 'rinvii', 'farvi', 'fronte', 'scelte', 'ambientali', 'indispensabile', 'posti', "'", "'", 'Torniamo', 'pensiero', 'popolazioni', 'minacciate', 'Venezia', 'territori', 'colpiti', 'sismi', 'o', 'alluvioni', 'aree', 'inquinate', 'sottolineare', 'tema', 't', 'utela', 'nostalgia', 'passato', 'società', 'bisogno', 'giovani', 'possibile', 'ancor', 'og', 'gi', 'durata', 'è', 'cresciuta', 'equilibri', 'demografici', 'spostati', 'nuova', 'condizione', 'impone', 'predisporre', 'confronti', 'anziani', 'preziosa', 'società', 'maggiori', 'cure', 'attenzioni', 'Occorre', 'investire', 'giovani', 'correttamente', 'retribuito', 'Favoriamo', 'formarsi', 'nuove', 'famiglie', 'Dobbiamo', 'riporre', 'fiducia', 'famiglie', 'italiane', 'grava', 'peso', 'maggiore', 'squilibri', 'sociali', 'affrontato', 'i', 'momenti', 'duri', 'superandoli', 'sacrificio', 'Fornire', 'sostegno', 'famiglie', 'vuol', 'possano', 'realizzare', 'i', 'progetti', 'i', 'valori', 'rafforzandone', 'senso', 'civico', 'rispetto', 'pubblica', 'Argina', 'agg', 'ressività', 'prepotenze', 'meschinità', 'lacerazioni', 'regole', 'convivenza', 'associazione', 'disabili', 'donato', 'Natale', 'sedia', 'semplice', 'conserverò', 'enti', 'perdiamo', 'Esprime', 'appieno', 'vero', 'senso', 'convivenza', 'vittime', 'dovere', 'dolore', 'familiari', 'colleghi', 'estinguersi', 'vorrei', 'ra', 'voglio', 'definire', 'storia', 'sentimento', 'profondo', 'gente', 'municipio', 'atteso', 'mettessero', 'i', 'dipendenti', 'uscendone', 'Sacrificando', 'propria', 'Senso', 'civico', 'senso', 'misura', 'devono', 'appartenere', 'frequenta', 'social', 'o', 'ccasione', 'ampliare', 'conoscenze', 'poter', 'dialogare', 'tanti', 'esprimere', 'proprie', 'idee', 'ascoltare', 'attenzione', 'rispetto', "'", "'", 'trasforma', 'strumento', 'denigrare', 'deformando', 'i', 'fatti', 'Sovente', 'ricorren', 'do', 'profili', 'fittizi', 'soggetti', 'inesistenti', 'alterare', 'scambio', 'opinioni', 'ingenerare', 'allarmi', 'trarre', 'vantaggio', 'diffusione', 'notizie', 'false', 'mosaico', 'compone', 'società', 'italiana', 'tante', 'tessere', 'preziose', 'Penso', 'altre', 'l', 'università', 'centri', 'ricerca', 'prestigiose', 'istituzioni', 'cultura', 'conosciuto', 'apprezzato', 'tante', 'occasioni', 'svolge', 'costellazione', 'tratta', 'patrimonio', 'inestimabile', 'idee', 'energie', 'costruire', 'essenziale', 'disponibile', 'conosciuto', 'raccontato', 'condiviso', 'rimossi', 'ostacoli', 'reso', 'agevole', 'senso', 'ruolo', 'fondamentale', 'è', 'assegnato', 'media', 'particolare', 'servizio', 'pubblico', 'bisogno', 'preparazione', 'competenze', 'vede', 'affiorare', 'tendenza', 'prender', 'posizione', 'ancor', 'informarsi', 'cultura', 'è', 'propulsore', 'qualità', 'rende', 'tessuto', 'sociale', 'solido', 'o', 'è', 'Capitale', 'cultura', 'europea', 'spirito', 'rivolgo', 'auguri', 'Parma', 'straordinario', 'patrimonio', 'umano', 'artistico', 'domani', 'Capitale', 'italiana', 'cultura', '2020', 'saluto', 'particolarmente', 'grato', 'sentito', 'rivolgo', 'Papa', 'Francesco', 'Vescovo', 'Roma', 'esercita', 'alto', 'magistero', 'saggezza', 'coraggio', 'mostra', 'amare', 'partire', 'versano', 'condizioni', 'bisogno', 'praticando', 'solidarietà', 'reca', 'beneficio', 'comunità', 'civile', 'ospita', 'vorrei', 'rivolgere', 'saluto', 'particolare', 'giornate', 'festive', 'assicurano', 'funzionamento', 'servizi', 'necessari', 'comune', 'ruoli', 'compiti', 'operano', 'beneficio', 'Repubblica', 'cittadini', 'saluto', 'Luca', 'Parmitano', 'astronauta', 'italiano', 'comando', 'stazione', 'spaziale', 'internazionale', 'principali', 'protagonisti', "'", "'", 'lassù', 'navicella', 'collegati', 'avverte', 'appaiano', 'incomprensibili', 'dissennate', 'inimicizie', 'contrapposizioni', 'violenze', 'pianeta', 'piccolo', 'raccolto', 'trasmesso', 'messaggio', 'speranza', 'consiste', 'possibilità', 'raggiungere', 'rivolgo', '!', 'Buon', '2020', '!']

# %%
type(Text_list)
# Out:
# list

# %%
# convert to str for work in .generate(doc1_str)
doc1_str = ','.join(Text_list)
type(doc1_str)
# Out:
# str

# %% [markdown]
# -------

# %% [markdown]
# Generate Word Cloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
# add Characters to stopwords list
exep = set(['lunga', 'senso'])
stopwords = set(STOPWORDS).union(exep)

# %%
# Make the figure
Word_Cloud = WordCloud(
    background_color = 'black',
    #max_words=20,
    width=2400,height=1600, 
    normalize_plurals= True,
    stopwords = stopwords,
    margin=3
).generate(doc1_str)

plt.imshow(Word_Cloud, interpolation='bilinear')
plt.title(
    'Word Cloud del messaggio di fine anno \n del Presidente della Repubblica Sergio Mattarella',
    fontweight = 'bold',
    fontsize=12
)
plt.axis("off")
#plt.figure(figsize=(15,10))
plt.margins(x=0, y=0)
plt.savefig('Wc_Discorso_integrale_mattarella.png')
plt.show()
